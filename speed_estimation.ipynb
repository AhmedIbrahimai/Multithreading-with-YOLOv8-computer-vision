# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.1.1
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author: Glenn Jocher, Ayush Chaurasia, Jing Qiu
# Author-email:
# License: AGPL-3.0
# Location: C:\Users\amb\anaconda5\envs\ultralytics\Lib\site-packages
# Requires: hub-sdk, matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
# !pip install -U ultralytics

# %%
from ultralytics import YOLO
from ultralytics.solutions import speed_estimation
import cv2

model = YOLO("yolov8n.pt")
names = model.model.names

cap = cv2.VideoCapture("highwayy.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("speed_estimatioon.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               fps,
                               (w, h))

line_pts = [(0, 360), (1280, 360)]

# Init speed-estimation obj
speed_obj = speed_estimation.SpeedEstimator()
speed_obj.set_args(reg_pts=line_pts,
                   names=names,
                   view_img=True)

while cap.isOpened():

    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    tracks = model.track(im0, persist=True, show=False)

    im0 = speed_obj.estimate_speed(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 cars, 1310.0ms
# Speed: 13.3ms preprocess, 1310.0ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1410.9ms
# Speed: 48.0ms preprocess, 1410.9ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2915.1ms
# Speed: 19.0ms preprocess, 2915.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1555.2ms
# Speed: 17.0ms preprocess, 1555.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1517.1ms
# Speed: 18.0ms preprocess, 1517.1ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1596.1ms
# Speed: 15.0ms preprocess, 1596.1ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2249.7ms
# Speed: 314.8ms preprocess, 2249.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1444.5ms
# ...

# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors, Annotator

model = YOLO("yolov8n.pt")
names = model.model.names
cap = cv2.VideoCapture("highwayy.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('visioneye-pinpoint.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (-10, h)

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0)
    boxes = results[0].boxes.xyxy.cpu()
    clss = results[0].boxes.cls.cpu().tolist()

    annotator = Annotator(im0, line_width=2)

    for box, cls in zip(boxes, clss):
        annotator.box_label(box, label=names[int(cls)], color=colors(int(cls)))
        annotator.visioneye(box, center_point)

    out.write(im0)
    cv2.imshow("visioneye-pinpoint", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 cars, 1542.8ms
# Speed: 16.6ms preprocess, 1542.8ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1623.1ms
# Speed: 182.9ms preprocess, 1623.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1179.4ms
# Speed: 39.0ms preprocess, 1179.4ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1004.5ms
# Speed: 8.0ms preprocess, 1004.5ms inference, 27.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1032.4ms
# Speed: 19.0ms preprocess, 1032.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 797.4ms
# Speed: 35.0ms preprocess, 797.4ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 801.2ms
# Speed: 8.0ms preprocess, 801.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 656.5ms
# ...

# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors, Annotator

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture("highwayy.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('visioneye-pinpoint.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (-10, h)

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    annotator = Annotator(im0, line_width=2)

    results = model.track(im0, persist=True)
    boxes = results[0].boxes.xyxy.cpu()

    if results[0].boxes.id is not None:
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, track_id in zip(boxes, track_ids):
            annotator.box_label(box, label=str(track_id), color=colors(int(track_id)))
            annotator.visioneye(box, center_point)

    out.write(im0)
    cv2.imshow("visioneye-pinpoint", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 cars, 1382.2ms
# Speed: 34.0ms preprocess, 1382.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1758.5ms
# Speed: 198.9ms preprocess, 1758.5ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 945.1ms
# Speed: 66.0ms preprocess, 945.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 677.8ms
# Speed: 25.0ms preprocess, 677.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 607.2ms
# Speed: 8.0ms preprocess, 607.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 604.9ms
# Speed: 6.0ms preprocess, 604.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 560.6ms
# Speed: 10.0ms preprocess, 560.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 607.9ms
# ...

# %%
import threading
import cv2
from ultralytics import YOLO


def run_tracker_in_thread(filename, model, file_index):
    
    video = cv2.VideoCapture(filename)  # Read the video file

    while True:
        ret, frame = video.read()  # Read the video frames

        # Exit the loop if no more frames in either video
        if not ret:
            break

        # Track objects in frames if available
        results = model.track(frame, persist=True)
        res_plotted = results[0].plot()
        cv2.imshow(f"Tracking_Stream_{file_index}", res_plotted)

        key = cv2.waitKey(1)
        if key == ord('q'):
            break

    # Release video sources
    video.release()


# Load the models
model1 = YOLO('yolov8n.pt')
model2 = YOLO('yolov8n-seg.pt')

# Define the video files for the trackers
video_file1 = "highwayy.mp4"  # Path to video file, 0 for webcam
video_file2 = "highwayy.mp4"  # Path to video file, 0 for webcam, 1 for external camera

# Create the tracker threads
tracker_thread1 = threading.Thread(target=run_tracker_in_thread, args=(video_file1, model1, 1))
tracker_thread2 = threading.Thread(target=run_tracker_in_thread, args=(video_file2, model2, 2))

# Start the tracker threads
tracker_thread1.start()
tracker_thread2.start()

# Wait for the tracker threads to finish
tracker_thread1.join()
tracker_thread2.join()

# Clean up and close windows
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 cars, 3364.1ms
# Speed: 10.0ms preprocess, 3364.1ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 4339.0ms
# Speed: 10.0ms preprocess, 4339.0ms inference, 155.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2334.5ms
# Speed: 26.5ms preprocess, 2334.5ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1900.5ms
# Speed: 43.1ms preprocess, 1900.5ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 795.8ms
# Speed: 18.0ms preprocess, 795.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 954.8ms
# Speed: 20.0ms preprocess, 954.8ms inference, 46.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 900.8ms
# Speed: 7.0ms preprocess, 900.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1965.3ms
# ...
